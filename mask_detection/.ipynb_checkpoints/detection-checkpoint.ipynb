# %%
import matplotlib

# %%
matplotlib.use('TkAgg')

# %%
import os 
import cv2 as cv 
import ultralytics
from sort import *
from ultralytics import YOLO
pred= YOLO('2_class.pt')

# %% [markdown]
# There are 3 functions here i.e. mask_detection(),  video() and save_video(). All will  detect face with mask and without
# mask wtih confidence level. They will also count total number of face with masks in the video and for the single frame
# As the name suggests, video will just play video with detection whereas save_video will save the video as well. In mask_detection(), it will detect face with mask or not in the image
#
# Use 'best_7.pt' to count total number of mask came in the video. Here mask class number is 0 need to adjust code
# Use '2_class.pt' to detect face with and without mask.

# %%
def mask_detector(inp):
    img = cv.imread(inp)
    result = pred(img, iou = 0.1)
    mc = 0
    nc = 0
    for r in result:
        cl_name = r.names
        for box in r.boxes.data:
            
            x1, y1, x2, y2, conf, clas = box
            x1, y1, x2, y2, conf, clas = int(x1), int(y1), int(x2), int(y2), int(conf*100), int(clas)
            
            text = cl_name[clas] +f': {conf}'
            cv.rectangle(img, (x1,y1), (x2,y2), (255,0,255),2)
            if clas == 1:
                mc +=1
                cv.putText(img, text, (max(0,x1-5), max(10, y1-5)), 
                      cv.FONT_HERSHEY_COMPLEX, 0.5, (25, 255 ,105),1)
            else:
                nc +=1
                cv.putText(img, text, (max(0,x1-5), max(10, y1-5)), 
                      cv.FONT_HERSHEY_COMPLEX, 0.5, (25, 255 ,105),1)
    cv.putText(img, f'Face with Masks: {mc}' ,(10,20),cv.FONT_HERSHEY_COMPLEX, 0.6, (100, 0 ,255),1)
    cv.putText(img, f'Face with no Mask: {nc}' ,(10,50),cv.FONT_HERSHEY_COMPLEX, 0.6, (100, 0 ,255),1 )
    
    cv.imshow('detection', img)
    cv.waitKey(0)
    cv.destroyAllWindows()

# %%
def save_video():
    inp = input('Give path to the video')
    out = input('Give path for the output')
    

    
    
    cap = cv.VideoCapture(inp)
    framewidth = int(cap.get(cv.CAP_PROP_FRAME_WIDTH))
    frameheight = int(cap.get(cv.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv.CAP_PROP_FPS))
    fourcc = cv.VideoWriter_fourcc(*'MP4V')
    output = cv.VideoWriter(out, fourcc, fps, (framewidth, frameheight))
    tracker = Sort(max_age = 20, min_hits = 3, iou_threshold = 0.3)
    #limit = [0,200,620,200]
    
    track_id = []
    while True:
        ret, img = cap.read()
        if ret == True:
            results = pred(img, stream = True, iou = 0.1, conf = 0.35)
            detection = np.empty((0,5))
            count = 0
            for result in results:
                
                for i in result.boxes:
                    
                    cls = i.cls
                    if int(cls) == 1:
                        count +=1
                        conf = i.conf
                        x1,y1,x2,y2 = i.xyxy[0]
                        x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
                        #cv.rectangle(img, (x,y), (x1,y1), (255,0,255),2)
                        #cv.putText(img, f'Mask{round(float(conf),2)}' ,(x,y-10),cv.FONT_HERSHEY_COMPLEX, 0.8, (25, 155 ,125),2)
                        array = np.array([x1,y1,x2,y2, int(conf*100)])
                        detection = np.vstack((detection, array))
            
                    elif int(cls) == 0:
                        conf = i.conf
                        x1,y1,x2,y2 = i.xyxy[0]
                        x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
                        cv.rectangle(img, (x1,y1), (x2,y2), (255,0,255),2)
                        cv.putText(img, f'FACE{round(float(conf),2)}' ,(x1,y1-10),cv.FONT_HERSHEY_COMPLEX, 0.5, (25, 155 ,125),2)
                        
            track = tracker.update(detection)
           
            for tr in track:
                x1,y1,x2,y2,iden = tr
                x1,y1,x2,y2,iden = int(x1),int(y1),int(x2),int(y2), int(iden)
                cv.rectangle(img, (x1,y1),(x2,y2), (255,0,255), 2)
                cv.putText(img, f'Mask ID: {str(iden)} ', (max(0,x1-15), max(35, y1-5)), 
                              cv.FONT_HERSHEY_COMPLEX, 0.5, (50,125, 0), 2)
                #cx, cy = x1+ (x2-x1)//2, y1 +(y2-y1)
               
           
                if (iden not in track_id):
                #if( limit[0]<cx<limit[2]) &( limit[1] -20<cy< limit[1] + 2) &(iden not in track_id):
                    
                    track_id.append(iden)
            cv.putText(img, f'Total Masks: {len(track_id)}' ,(10,20),cv.FONT_HERSHEY_COMPLEX, 0.6, (100, 0 ,255),2 )
            cv.putText(img, f'Per scene: {count}' ,(10,50),cv.FONT_HERSHEY_COMPLEX, 0.6, (100, 0 ,255),2 )
                
            
            cv.imshow('img', img)
            output.write(img)
            if cv.waitKey(1) & 0xFF == ord('x'):
                break
        else:
            break
            
    output.release()
    cap.release()
    cv.destroyAllWindows()

# %%
def video():
    
    path = input('Give path of the video')
    cap = cv.VideoCapture(path)
    tracker = Sort(max_age = 20, min_hits = 3, iou_threshold = 0.3)


    track_id = []
    while True:
        ret, img = cap.read()
        if ret == True:
            results = pred(img, stream = True, iou = 0.1, conf = 0.35)
            detection = np.empty((0,5))
            count = 0
            for result in results:
                
                for i in result.boxes:
                    
                    cls = i.cls
                    if int(cls) == 1:
                        count +=1
                        conf = i.conf
                        x1,y1,x2,y2 = i.xyxy[0]
                        x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
                        #cv.rectangle(img, (x,y), (x1,y1), (255,0,255),2)
                        #cv.putText(img, f'Mask{round(float(conf),2)}' ,(x,y-10),cv.FONT_HERSHEY_COMPLEX, 0.8, (25, 155 ,125),2)
                        array = np.array([x1,y1,x2,y2, int(conf*100)])
                        detection = np.vstack((detection, array))
            
                    elif int(cls) == 0:
                        conf = i.conf
                        x1,y1,x2,y2 = i.xyxy[0]
                        x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
                        cv.rectangle(img, (x1,y1), (x2,y2), (255,0,255),2)
                        cv.putText(img, f'FACE{round(float(conf),2)}' ,(x1,y1-10),cv.FONT_HERSHEY_COMPLEX, 0.8, (25, 155 ,125),2)
                        
            track = tracker.update(detection)
           
            for tr in track:
                x1,y1,x2,y2,iden = tr
                x1,y1,x2,y2,iden = int(x1),int(y1),int(x2),int(y2), int(iden)
                cv.rectangle(img, (x1,y1),(x2,y2), (255,0,255), 2)
                cv.putText(img, f'Mask ID: {str(iden)} ', (max(0,x1-15), max(35, y1-5)), 
                              cv.FONT_HERSHEY_COMPLEX, 0.5, (50,125, 0), 2)
                #cx, cy = x1+ (x2-x1)//2, y1 +(y2-y1)
               
           
                if (iden not in track_id):
                #if( limit[0]<cx<limit[2]) &( limit[1] -20<cy< limit[1] + 2) &(iden not in track_id):
                    
                    track_id.append(iden)
            cv.putText(img, f'Total Masks: {len(track_id)}' ,(10,20),cv.FONT_HERSHEY_COMPLEX, 0.6, (100, 0 ,255),2 )
            cv.putText(img, f'Per scene: {count}' ,(10,50),cv.FONT_HERSHEY_COMPLEX, 0.6, (100, 0 ,255),2 )
                
            
            cv.imshow('img', img)
           
            if cv.waitKey(1) & 0xFF == ord('x'):
                break
        else:
            break
            
 
    cap.release()
    cv.destroyAllWindows()

# %%
video()
# Out:
# Give path of the video Test_video1.mp4
# 0: 384x640 4 Masks, 1619.9ms
# Speed: 568.3ms preprocess, 1619.9ms inference, 164.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 233.0ms
# Speed: 105.2ms preprocess, 233.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 838.6ms
# Speed: 3.2ms preprocess, 838.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 143.9ms
# Speed: 3.5ms preprocess, 143.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 126.4ms
# Speed: 4.3ms preprocess, 126.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 146.3ms
# Speed: 6.3ms preprocess, 146.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 160.9ms
# Speed: 2.8ms preprocess, 160.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 162.8ms
# Speed: 13.8ms preprocess, 162.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 214.6ms
# Speed: 4.4ms preprocess, 214.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 299.3ms
# Speed: 4.4ms preprocess, 299.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 204.4ms
# Speed: 5.8ms preprocess, 204.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 147.4ms
# Speed: 7.0ms preprocess, 147.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 141.4ms
# Speed: 3.0ms preprocess, 141.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 136.9ms
# Speed: 4.2ms preprocess, 136.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 122.7ms
# Speed: 3.3ms preprocess, 122.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 141.5ms
# Speed: 8.9ms preprocess, 141.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 136.4ms
# Speed: 4.1ms preprocess, 136.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 128.6ms
# Speed: 6.9ms preprocess, 128.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 132.6ms
# Speed: 3.4ms preprocess, 132.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 163.5ms
# Speed: 6.3ms preprocess, 163.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 184.7ms
# Speed: 3.8ms preprocess, 184.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 128.8ms
# Speed: 2.8ms preprocess, 128.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 141.8ms
# Speed: 2.6ms preprocess, 141.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 176.5ms
# Speed: 3.5ms preprocess, 176.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 128.1ms
# Speed: 3.3ms preprocess, 128.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 159.9ms
# Speed: 2.4ms preprocess, 159.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 197.7ms
# Speed: 3.2ms preprocess, 197.7ms inference, 20.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 248.1ms
# Speed: 583.1ms preprocess, 248.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Masks, 182.7ms
# Speed: 3.6ms preprocess, 182.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 161.9ms
# Speed: 8.1ms preprocess, 161.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Masks, 179.2ms
# Speed: 16.2ms preprocess, 179.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 130.4ms
# Speed: 2.8ms preprocess, 130.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 199.5ms
# Speed: 8.7ms preprocess, 199.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 129.6ms
# Speed: 2.9ms preprocess, 129.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 144.3ms
# Speed: 5.3ms preprocess, 144.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Masks, 181.9ms
# Speed: 4.9ms preprocess, 181.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Masks, 141.4ms
# Speed: 2.5ms preprocess, 141.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Masks, 133.9ms
# Speed: 3.1ms preprocess, 133.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4
ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 139.6ms
# Speed: 3.6ms preprocess, 139.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 132.5ms
# Speed: 3.4ms preprocess, 132.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 120.4ms
# Speed: 4.3ms preprocess, 120.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 128.5ms
# Speed: 5.1ms preprocess, 128.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 127.6ms
# Speed: 5.5ms preprocess, 127.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 135.9ms
# Speed: 4.7ms preprocess, 135.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 114.9ms
# Speed: 5.1ms preprocess, 114.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 134.7ms
# Speed: 3.8ms preprocess, 134.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 122.1ms
# Speed: 4.8ms preprocess, 122.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 139.5ms
# Speed: 4.3ms preprocess, 139.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 162.0ms
# Speed: 6.0ms preprocess, 162.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 122.2ms
# Speed: 5.3ms preprocess, 122.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 119.8ms
# Speed: 3.3ms preprocess, 119.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 131.5ms
# Speed: 5.9ms preprocess, 131.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 138.5ms
# Speed: 4.4ms preprocess, 138.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 126.1ms
# Speed: 5.3ms preprocess, 126.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 128.8ms
# Speed: 4.1ms preprocess, 128.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 159.5ms
# Speed: 4.9ms preprocess, 159.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 126.4ms
# Speed: 5.2ms preprocess, 126.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 129.7ms
# Speed: 4.1ms preprocess, 129.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 128.5ms
# Speed: 3.7ms preprocess, 128.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 116.3ms
# Speed: 3.0ms preprocess, 116.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 137.0ms
# Speed: 3.2ms preprocess, 137.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 119.4ms
# Speed: 4.5ms preprocess, 119.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 113.5ms
# Speed: 3.1ms preprocess, 113.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 103.0ms
# Speed: 21.6ms preprocess, 103.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 108.1ms
# Speed: 3.0ms preprocess, 108.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 99.7ms
# Speed: 10.8ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 Masks, 152.0ms
# Speed: 2.8ms preprocess, 152.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
#Press x to close
print('''Choose the option:
press 1 to play the video only
press 2 to play and save the video as well
press 3 to detect mask on face in images
press x to exit''')
while True:
    x = input('Your input')
    if x == '1':
        video()
        print('''Choose the option:
        press 1 to play the video only
        press 2 to play and save the video as well
        press 3 to detect mask on face in images
        press x to quit''')
        x = input('Your input')
    elif x == '2':
        save_video()
        print('''Choose the option:
        press 1 to play the video only
        press 2 to play and save the video as well
        press 3 to detect mask on face in images
        press x to quit''')
        x = input('Your input')
    elif x == '3':
        mask_detection()
        print('''Choose the option:
        press 1 to play the video only
        press 2 to play and save the video as well
        press 3 to detect mask on face in images
        press x to quit''')
        x = input('Your input')
    elif x not in ['x', '1', '2', '3']:
        print('try again')
        x = input('Your input')
       
    else:
         break
    break
# Out:
# Choose the option:
# press 1 to play the video only
# press 2 to play and save the video as well
# press x to quit
# Your input 1
# Give path of the video D:\computer_vision\wobo\test\Test_video1.mp4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 9
#       7 x = input('Your input')
#       8 if x == '1':
# ----> 9     video()
#      10     print('''Choose the option:
#      11     press 1 to play the video only
#      12     press 2 to play and save the video as well
#      13     press x to quit''')
#      14     x = input('Your input')
#
# Cell In[23], line 12, in video()
#      10 ret, img = cap.read()
#      11 if ret == True:
# ---> 12     results = pred(img, stream = True, iou = 0.1, conf = 0.35)
#      13     detection = np.empty((0,5))
#      14     count = 0
#
# NameError: name 'pred' is not defined
